# %% [markdown]
# <a href="https://colab.research.google.com/github/tilin1841j/localidaddes_y_poblacion_bogota/blob/main/localidaddes_y_poblacion_bogota.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import pandas as pd

# !pip install contextily
import contextily as cx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 17.8 MB/s eta 0:00:00
# ...

# %%
localidades = gpd.read_file("localidades_bogota.json")
localidades
# Out:
#     OBJECTID           LocNombre                            LocAAdmini  \
# 0         81      ANTONIO NARIÑO                   Acuerdo 117 de 2003
# 1         82          TUNJUELITO                   Acuerdo 117 de 2003
# 2         83  RAFAEL URIBE URIBE                   Acuerdo 117 de 2003
# 3         84          CANDELARIA                   Acuerdo 117 de 2003
# 4         85      BARRIOS UNIDOS                     Acuerdo 8 de 1977
# 5         86         TEUSAQUILLO                     Acuerdo 8 de 1977
# 6         87       PUENTE ARANDA                     Acuerdo 8 de 1977
# 7         88        LOS MARTIRES                     Acuerdo 8 de 1977
# 8         89             SUMAPAZ                     Acuerdo 9 de 1986
# 9         90             USAQUEN  Acuerdo 8 de 1977 y Res 1751 de 2016
# 10        91           CHAPINERO  Acuerdo 8 de 1977 y Res 1751 de 2016
# 11        92            SANTA FE                   Acuerdo 117 de 2003
# ...

# %%
localidades.plot()
# Out:
# <Axes: >

# %%
Población =pd.read_csv("poblacion_bogota.csv", encoding='latin1', delimiter=";")
Población
# Out:
#          Año  Cod_Loc Localidad     Sexo  Edad Grupo_Edad  Población
# 0       2005        1   Usaquén  Hombres     0    00 a 04       2909
# 1       2005        1   Usaquén  Hombres     1    00 a 04       2954
# 2       2005        1   Usaquén  Hombres     2    00 a 04       2919
# 3       2005        1   Usaquén  Hombres     3    00 a 04       2989
# 4       2005        1   Usaquén  Hombres     4    00 a 04       3079
# ...      ...      ...       ...      ...   ...        ...        ...
# 131497  2035        0    Bogotá  Mujeres    96    95 a 99       1192
# 131498  2035        0    Bogotá  Mujeres    97    95 a 99        847
# 131499  2035        0    Bogotá  Mujeres    98    95 a 99        590
# 131500  2035        0    Bogotá  Mujeres    99    95 a 99        403
# 131501  2035        0    Bogotá  Mujeres   100  100 o más        720
#
# [131502 rows x 7 columns]

# %%
Población_24 =Población[Población['Año'] == 2024]
Población_24
# Out:
#          Año  Cod_Loc Localidad     Sexo  Edad Grupo_Edad  Población
# 76760   2024        1   Usaquén  Hombres     0    00 a 04       3128
# 76761   2024        1   Usaquén  Hombres     1    00 a 04       3147
# 76762   2024        1   Usaquén  Hombres     2    00 a 04       3139
# 76763   2024        1   Usaquén  Hombres     3    00 a 04       3106
# 76764   2024        1   Usaquén  Hombres     4    00 a 04       3037
# ...      ...      ...       ...      ...   ...        ...        ...
# 129275  2024        0    Bogotá  Mujeres    96    95 a 99        981
# 129276  2024        0    Bogotá  Mujeres    97    95 a 99        771
# 129277  2024        0    Bogotá  Mujeres    98    95 a 99        598
# 129278  2024        0    Bogotá  Mujeres    99    95 a 99        464
# 129279  2024        0    Bogotá  Mujeres   100  100 o más       1219
#
# [4242 rows x 7 columns]

# %%
grupos= Población_24.groupby("Localidad")
print(grupos)

# %%
totalPoblacionLocaliad= grupos["Población"].sum()
print(totalPoblacionLocaliad)
# Out:
# Localidad
# Antonio Nariño          84979
# Barrios Unidos         156268
# Bogotá                7929539
# Bosa                   733740
# Chapinero              182103
# Ciudad Bolívar         666809
# Engativá               819441
# Fontibón               408155
# Kennedy               1037929
# La Candelaria           18675
# Los Mártires            83001
# Puente Aranda          258034
# Rafael Uribe Uribe     391588
# San Cristóbal          409106
# Santa Fe               107906
# Suba                  1313453
# Sumapaz                  3926
# Teusaquillo            165438
# Tunjuelito             184492
# Usaquén                594611
# Usme                   414995
# Name: Población, dtype: int64

# %%
dfPoblacion= totalPoblacionLocaliad.reset_index()
dfPoblacion
# Out:
#              Localidad  Población
# 0       Antonio Nariño      84979
# 1       Barrios Unidos     156268
# 2               Bogotá    7929539
# 3                 Bosa     733740
# 4            Chapinero     182103
# 5       Ciudad Bolívar     666809
# 6             Engativá     819441
# 7             Fontibón     408155
# 8              Kennedy    1037929
# 9        La Candelaria      18675
# 10        Los Mártires      83001
# 11       Puente Aranda     258034
# 12  Rafael Uribe Uribe     391588
# 13       San Cristóbal     409106
# 14            Santa Fe     107906
# 15                Suba    1313453
# 16             Sumapaz       3926
# 17         Teusaquillo     165438
# 18          Tunjuelito     184492
# 19             Usaquén     594611
# 20                Usme     414995

# %%
dfPoblacion["Localidad"]= dfPoblacion["Localidad"].str.upper()

dfPoblacion
# Out:
#              Localidad  Población
# 0       ANTONIO NARIÑO      84979
# 1       BARRIOS UNIDOS     156268
# 2               BOGOTÁ    7929539
# 3                 BOSA     733740
# 4            CHAPINERO     182103
# 5       CIUDAD BOLÍVAR     666809
# 6             ENGATIVÁ     819441
# 7             FONTIBÓN     408155
# 8              KENNEDY    1037929
# 9           CANDELARIA      18675
# 10        LOS MÁRTIRES      83001
# 11       PUENTE ARANDA     258034
# 12  RAFAEL URIBE URIBE     391588
# 13       SAN CRISTÓBAL     409106
# 14            SANTA FE     107906
# 15                SUBA    1313453
# 16             SUMAPAZ       3926
# 17         TEUSAQUILLO     165438
# 18          TUNJUELITO     184492
# 19             USAQUÉN     594611
# 20                USME     414995

# %% [markdown]
# # Quitar las tildes de la columna Localidad del dfPoblacion

# %%
dfPoblacion['Localidad']

def replace_accents(input_str):
  replacements ={
      'Á': 'A',
      'É': 'E',
      'Í': 'I',
      'Ó': 'O',
      'Ú': 'U',
  }

  for accented_char, unaccented_char in replacements.items():
    input_str = input_str.replace(accented_char, unaccented_char)
  return input_str

dfPoblacion['Localidad'] = dfPoblacion['Localidad'].apply(replace_accents)

# %%
dfPoblacion
# Out:
#              Localidad  Población
# 0       ANTONIO NARIÑO      84979
# 1       BARRIOS UNIDOS     156268
# 2               BOGOTA    7929539
# 3                 BOSA     733740
# 4            CHAPINERO     182103
# 5       CIUDAD BOLIVAR     666809
# 6             ENGATIVA     819441
# 7             FONTIBON     408155
# 8              KENNEDY    1037929
# 9           CANDELARIA      18675
# 10        LOS MARTIRES      83001
# 11       PUENTE ARANDA     258034
# 12  RAFAEL URIBE URIBE     391588
# 13       SAN CRISTOBAL     409106
# 14            SANTA FE     107906
# 15                SUBA    1313453
# 16             SUMAPAZ       3926
# 17         TEUSAQUILLO     165438
# 18          TUNJUELITO     184492
# 19             USAQUEN     594611
# 20                USME     414995

# %%
filas= dfPoblacion["Localidad"]== "LA CANDELARIA"
filas

# %%
columna= 'Localidad'
dfPoblacion.loc[filas,columna]= "CANDELARIA"
dfPoblacion

# %%
merge = localidades.merge(dfPoblacion, left_on= "LocNombre", right_on= "Localidad")

merge

# %%
merge.drop("Localidad", axis=1, inplace= True)
merge

# %%
mapa_2= merge.plot(
    column= 'Población',
    figsize=(15,15),
    edgecolor='black',
    cmap= 'tab20',
    legend= True,

)

cx.add_basemap(mapa_2, crs=merge.crs.to_string())

# %%
mapa_2= localidades.plot(
    column= 'LocNombre',
    figsize=(15,15),
    edgecolor='black',
    cmap= 'tab20',
    legend= True,
    legend_kwds ={
        'loc':'upper left'
    }
)
